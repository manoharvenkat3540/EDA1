# %% [markdown]
# **functions**
# - function means a block of code which we can use manytimes

# %% [markdown]
# - while we are defining function if nothing mention means it is called as function without arguments

# %%
import random
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001AA09342330>>

# %%
def <function_name>():
    codeline

# %%
def addition():
    num=10
    num1=3
    add=num+num1
    print(add)

# %%
# function name: addition
#in order to execute the code lines we needto call the function

# %%
addition
# Out:
# <function __main__.addition()>

# %%
addition()
# Out:
# 13

# %%
def addition1():
    num1=10
    print("num1 is:",num1)
    num2=30
    print("num2 is :",num2)
    add=num1+num2
    print(f"the addition od {num1} and {num2} is {add}")
addition1()
# Out:
# num1 is: 10
# num2 is : 30
# the addition od 10 and 30 is 40

# %% [markdown]
# **note**

# %% [markdown]
# - functionsmeans can be anything
# - some rules apcplicable as variable rules
# - whenever you  create function make sure indentation correctly
# - starting with keyword, ending with colon then code line start indentation
# - brackets means functions
# - never miss the brackets whenever you call function
# - if you want to execute the code we need to call the function
# - while you are calling the function if you see funtion or bound method.
# - which means you missed the brackets

# %% [markdown]
# **Function without arguments**

# %%
#wap to create the function for average
def average():
    num1=10
    num2=20
    avg=(num1+num2)/2
    print(avg)
average()
# Out:
# 15.0

# %%
#wap ask the user to enter radius find the area of the circle
def circle():
    n=eval(input("enter the radius:"))
    area_of_circle=3.14*n*n
    print(area_of_circle)
circle()
# Out:
# enter the radius: 34
# 3629.84

# %%
#wap ask the bill amount
#  ask the user how muvh tip you want to pay in percentage
# calculate total bill
def bill():
    amount=eval(input("enter the amount:"))
    tip=eval(input("enter the tip amount:"))
    total=(amount*tip)/100
    print(amount+total)
bill()
# Out:
# enter the amount: 1000
# enter the tip amount: 10
# 1100.0

# %%
def dollar():
    amount=eval(input("enter the amount:"))
    onedollar=eval(input("enter a one dollar:"))
    total=amount*onedollar
    print(total)
dollar()
# Out:
# enter the amount: 10
# enter a one dollar: 83.2
# 832.0

# %%
def tirangle():
    base=eval(input("enter a base"))
    height=eval(input("enter height:"))
    area_of_the_triangl=1/2*base*height
    print(area_of_the_triangl)
tirangle()
# Out:
# enter a base 10
# enter height: 20
# 100.0

# %%
def rectangle():
    length=eval(input("enter the length:"))
    breadth=eval(input("enter the breadth:"))
    area_of_the_rectangle=length*breadth
    print(area_of_the_rectangle)
rectangle()
# Out:
# enter the length: 10
# enter the breadth: 20
# 200

# %% [markdown]
# **functions with arguments**

# %% [markdown]
# - first look at how many arguments (**variables**) are there
# - in that how many input variables are three
# - how many output variables are there
# - input variables means user can defined
# - output variables means python gives the output
# - we can use only input variables as arguments inside the function

# %%
def addition2(num1,num2):
    add=num1+num2
    print(f"the addition of {num1} and {num2} is {add}")
addition2(10,20)
# Out:
# the addition of 10 and 20 is 30

# %% [markdown]
# **Default arguments**

# %%
def bill_pay():
    bill=eval(input("enter amount:"))
    tip_percentage=eval(input("enter the tip percentage:"))
    tip_amount=bill*tip_percentage/100
    total=tip_amount+bill
    print(total)
bill_pay()
# Out:
# enter amount: 10
# enter the tip percentage: 1
# 10.1

# %%
def bill_pay(bill,tip_percentage):
    tip_amount=bill*tip_percentage/100
    total=bill+tip_amount
    print(total)
bill_pay(1000,10)
# Out:
# 1100.0

# %%
def bill_pay(bill,tip_percentage=20):
    print("bill is:",bill)
    print("tip_per:",tip_percentage)
    tip_amount=bill*tip_percentage/100
    total=bill+tip_amount
    print(total)
bill_pay(1000)
# Out:
# bill is: 1000
# tip_per: 20
# 1200.0

# %%
def avg(num1,num2,num3=50):
    print(num1)
    print(num2)
    print(num3)
    a=(num1+num2+num3)/3
    print(a)
avg(30,40)

#here num1 and num2 are the positional arguments 
#num3 is default argument
# Out:
# 30
# 40
# 50
# 40.0

# %%
def avg(num1,num2=40,num3):
    print(num1)
    print(num2)
    print(num3)
    a=(num1+num2+num3)/3
    print(a)
avg(30,50)

#here num1 and num2 are the positional arguments 
#num3 is default argument
#default arguments always last
# Out:
#   Cell In[9], line 1
#     def avg(num1,num2=40,num3):
#                          ^
# SyntaxError: non-default argument follows default argument

# %% [markdown]
# **note**
# - default arguments always should be last

# %%
avg(num1,num2,num3=50):#w
avg(num1,num2=40,num3):#f
avg(num1=100,num2,num3):#f
avg(num1,num2=40,num3=50):#w
avg(num1=30,num2,num3=50):#f
avg(num1=30,num2=40,num3=50):#w

# %%
#case-1
def add(num1,num2=600):
    add=num1+num2
    print(add)
add(1000,2000)

#first we are defining function
#while define the function we given n2=600
#now we are calling the function
#while we are calling n2=2000
#so values will be overwrite
#python always takes the lates
# Out:
# 3000

# %%
#case-2
def add(num1,num2=600):
    num2=100
    add=num1+num2
    print(add)
add(1000,2000)

#step-1 : default the funtion  n2=600
#step-2 : call function n2=2000
#step-3 : running the function n2=100
# Out:
# 1100

# %%
#case-3
def add(num1,num2=600):
    num2=100
    add=num1+num2
    print(add)
num2=3000
add(1000,2000)
# Out:
# 1100

# %% [markdown]
# **Local variable and Global variable**
#
# - local variable means: the variable inside the function call
#
# - global variable means: the variable outside the function call
#
# - once you define the variable outside means , u can use those variables anywhere
#
# - you can use global variables inside the also
#
# - but you can not use local variable outside the function

# %%
def mul():
    a=10
    b=20
    mult=a*b
    print(mult)
mul()

#a,b aer the local variables
#these values we can not use outside the function
# Out:
# 200

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a=10
b=20
def mul():
    mult=a*b
    print(mult)
mul()

#global variable

# %%
a #global variable
# Out:
# 10

# %%
mult  #local variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 mult
#
# NameError: name 'mult' is not defined

# %%
#case 4
a1=100
b1=200
def add1(a1=1000):
    add=a1+b1
    print(add)
add1()

#step-1 : global variable intialization
#step-2 : define the function a1=1000
#step-3 : call the function a1=1000
#step-4: running the function a1=1000
# Out:
# 1200

# %%
a1
# Out:
# 100

# %%
#case 5
a1=100
b1=200
def add1(a1=1000):
    add=a1+b1
    print(add)
add1(a1=500)
# Out:
# 700

# %%
#case 6
a1=100
b1=200
def add1(a1=1000):
    add=a1+b1
    print(add)
add1(a1=500,b1=600)

# while defining function only one argument is there
# while calling we are providing two arguments
# it is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       5     add=a1+b1
#       6     print(add)
# ----> 7 add1(a1=500,b1=600)
#
# TypeError: add1() got an unexpected keyword argument 'b1'

# %%
#case 7
a1=100
b1=200
def add1(a1=1000,b1=10):
    add=a1+b1
    print(add)
add1(500,50)
# Out:
# 550

# %%
#case 8
a1=100
b1=200
def add1(a1=1000,b1=10):
    a1=50000
    add=a1+b1
    print(add)
add1(500,50)
# Out:
# 50050

# %%
#case 9
a1=100
b1=200
def add1(a1=1000,b1=10):
    a1=5000
    add=a1+b1
    print(add)
a1=900
add1(a1=2000)
# Out:
# 5010

# %%
#case 10
b1=200
def add11():
    a1=5000
    add=a1+b1
    print(add)
a1=6000
add11()

#b1=200
#define the function
#a1=6000
# Out:
# 5200

# %%
s=0
def add():
    s=s+10
    print(m)
add()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 5
#       3     s=s+10
#       4     print(m)
# ----> 5 add()
#
# Cell In[5], line 3, in add()
#       2 def add():
# ----> 3     s=s+10
#       4     print(m)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
s=0
def add():
    m=s+10
    print(m)
add()
# Out:
# 10

# %%
s=0
def add():
    c=s+10
    s=c
    print(s)
add()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[17], line 6
#       4     s=c
#       5     print(s)
# ----> 6 add()
#
# Cell In[17], line 3, in add()
#       2 def add():
# ----> 3     c=s+10
#       4     s=c
#       5     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
n11=10
def addition():
    n2=200+n11
    n3=n11+n22
    print(n11,n22,n33)
addition()

#step-1 n11=10
#step-2 define the function
#step-3 calling the function
#step-4 run the function
#       n11 is global variable passing inside the function(yes)
#       n22=200+n11=200+10=210
#       n33=10+n22=10+210=220
#       print(10,210,220)
# Out:
# 10 210 220

# %%
n3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 n3
#
# NameError: name 'n3' is not defined

# %% [markdown]
# **note**
#
# - if you give same variable as global and local
# - make sure that the variable should not use as value inside the function

# %%
s=0
def add():
    c=s+10
    s=c
    print(s)
add()

#step-1 s=0    global variable
#step-2 define the function
#step-3 calling the function
#step-4 running the function
#       c is local variable
#       we are connecting a new variable same like as global s

# %%
value=100
def greet():
    value=200
    print('hello')
greet()
print(value)
# Out:
# hello
# 100

# %%
value
# Out:
# 100

# %% [markdown]
# **Global keyword**
#
# - global keyword is used to take the local variable value outside the function

# %%
value=100
def greet():
    global value
    value=200
    print('hello')
greet()
print('value:',value)
# Out:
# hello
# value: 200

# %%
value
# Out:
# 200

# %%
n11=10
def addition():
    global n33,n22
    n22=200+n11
    n33=n11+n22
    print(n11,n22,n33)
addition()
print('n22:',n22)
print('n33:',n33)
# Out:
# 10 210 220
# n22: 210
# n33: 220

# %%
n33
# Out:
# 220

# %%
n22
# Out:
# 210

# %% [markdown]
# - outside the function is called global variables
# - inside the function is local varibale
# - local  variables can not use outside the function
# - if u want to use outside the function use global keyword

# %%
def mul(a,b):
    print(a*b)
    
mul(eval(input()),
    eval(input()))
# Out:
#  20
#  30
# 600

# %% [markdown]
# **Return**

# %% [markdown]
# - we can use the local variables or function outside the function using return
#
# - print is different
#
# - return is different
#
# - print is used to only print the values
#
# - thet value you can only see,but you can not use
#
# - if you want to to use outside we will use return

# %%
def average():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    print(avg,n3)
average()
# Out:
# 20.0 30

# %%
def average():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    return(avg)
avg=average()

#function is ready to return values to me
#so i need to store

# %%
avg
# Out:
# 20.0

# %%
def average():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    return(avg,n3)
avg,n3=average()

#how many values we are returning
#we will store each return values in diffenerent variable
#because two values are different
#if you use only variable to store: tupe

# %%
def sub():
    a=10
    b=20
    subb=b-a
    return(a,b,subb)
subb=sub()

# %%
subb
# Out:
# (10, 20, 10)

# %% [markdown]
# - without arguments
# - with arguments
# - local vs global
# - global keyword
# - return
# - function in functio
# - *kwargs :keyword argument

# %% [markdown]
# **unbond local eror**

# %%
num1=10    #gv
def fun1():
    num1=100  #lv
    print("inside the function:",num1)  
fun1()
# Out:
# inside the function: 100

# %%
num2=10
def fun2():
    num2=200
    print(num2)
fun2()
#when the local variable and global variable both are same
#you are try to access local variable befoe assign 
#then we will get the error
# Out:
# 200
# 10

# %%
a1=100
b1=200
def add():
    add1=a1+b1
    a1=2000
    print(add1)
add()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[15], line 7
#       5     a1=2000
#       6     print(add1)
# ----> 7 add()
#
# Cell In[15], line 4, in add()
#       3 def add():
# ----> 4     add1=a1+b1
#       5     a1=2000
#       6     print(add1)
#
# UnboundLocalError: cannot access local variable 'a1' where it is not associated with a value

# %%
a1=100
b1=200
def add11():
    add1=a1+b1
    print(add1)
add11()

#here no local cariables as same name as global variable
# Out:
# 300

# %%
a1=100
b1=200
def add11():
    a1=700
    b1=500
    add1=a1+b1
    print(add1)
add11()

#we are initilizing lv means same as gv
#aw are  using lv after initilization
# Out:
# 1200

# %%
a1=100
b1=200
def add11():
    add1=a1+b1
    a1=700
    b1=500
    print(add1)
add11()

#we are initilizing lv means same as gv
#we are  using lv before initilization
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[27], line 8
#       6     b1=500
#       7     print(add1)
# ----> 8 add11()
#
# Cell In[27], line 4, in add11()
#       3 def add11():
# ----> 4     add1=a1+b1
#       5     a1=700
#       6     b1=500
#
# UnboundLocalError: cannot access local variable 'a1' where it is not associated with a value

# %% [markdown]
# - Global variable
#
# - define the fiction
#
# - call the function
#
# - run the function

# %% [markdown]
# **function in function**

# %%
def greed1():
    print('hello good morning:')
def greed2():
    print('good night')

greed1()
greed2()
# Out:
# hello good morning:
# good night

# %%
def greed2():
    print('good night')
    
def greed1():
    print('hello good morning:')
    greed2()



greed1()
# Out:
# hello good morning:
# good night

# %%
def greed2():
    print('good night')
    greed1()
    
def greed1():
    print('hello good morning:')
    greed2()

greed1()
# Out:
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# hello good morning:
# good night
# ...

# %% [markdown]
# - fuctions with out argumrnts
# - function with arguments
# - function default arguments
# - global vs local variable
# - global keyword
# -

# %%
def total():
    user=eval(input("enter the distance:"))
    cutoff_distance=25
    if user>25:
        print("good news your charge is aplicable for only remaining of 25")
        chargeble_distance=user-cutoff_distance
        charge=eval(input("enter the charge:"))
        total=chargeble_distance*charge
        print(f"the total charge for extra {chargeble_distance} is {total}")
    else:
        print("free ride")
total()
# Out:
# enter the distance: 30
# good news your charge is aplicable for only remaining of 25
# enter the charge: 30
# the total charge for extra 5 is 150

# %%
def total(user,cutoff_distance,charge):
    if user>25:
        print("good news your charge is aplicable for only remaining of 25")
        chargeble_distance=user-cutoff_distance
        total=chargeble_distance*charge
        print(f"the total charge for extra {chargeble_distance} is {total}")
    else:
        print("free ride")
total(60,30,10)
# Out:
# good news your charge is aplicable for only remaining of 25
# the total charge for extra 30 is 300

# %%
def total(user,cutoff_distance):
    if user>25:
        print("good news your charge is aplicable for only remaining of 25")
        chargeble_distance=user-cutoff_distance
        charge=eval(input("enter the charge:"))
        total=chargeble_distance*charge
        print(f"the total charge for extra {chargeble_distance} is {total}")
    else:
        print("free ride")
total(30,20)
# Out:
# good news your charge is aplicable for only remaining of 25
# enter the charge: 40
# the total charge for extra 10 is 400

# %%
user=eval(input("enter the distance:"))
cutoff_distance=25
def total():
    global total
    if user>25:
        print("good news your charge is aplicable for only remaining of 25")
        chargeble_distance=user-cutoff_distance
        charge=eval(input("enter the charge:"))
        total=chargeble_distance*charge
        print(f"the total charge for extra {chargeble_distance} is {total}")
    else:
        print("free ride")
total()
print(total)
# Out:
# enter the distance: 40
# good news your charge is aplicable for only remaining of 25
# enter the charge: 30
# the total charge for extra 15 is 450
# 450

# %%
user=eval(input("enter the distance:"))
cutoff_distance=25
def total11():
    if user>25:
        print("good news your charge is aplicable for only remaining of 25")
        chargeble_distance=user-cutoff_distance
        charge=eval(input("enter the charge:"))
        total=chargeble_distance*charge
        print(f"the total charge for extra {chargeble_distance} is {total}")
    else:
        cost=100
        return(total)
total=total11()
print(total)
# Out:
# enter the distance: 23
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[41], line 13
#      11         cost=100
#      12         return(total)
# ---> 13 total=total11()
#      14 print(total)
#
# Cell In[41], line 12, in total11()
#      10 else:
#      11     cost=100
# ---> 12     return(total)
#
# UnboundLocalError: cannot access local variable 'total' where it is not associated with a value

# %%
#first create 4 individaul function
#fun1 : add
#fun2 : sub
#fun3 : mul
#fun4 : div
#create a main function name :calculator
#inside main function
#print some statements
#option1: addition
#option2: sub, option3: mul opt:4
#option=eval(input('1-4')
#a value
#b value
#if option==1:
#   add function
#if option==2:
#   sub function
#if option==3:
#   mul function
#if option==4:
#   div function

def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
def calculator():
    print("option1 = addition:")
    print("option2 = substraction:")
    print("option1 = dicision:")
    print("option4 = multiplication:")
    a=eval(input("enter a:"))
    b=eval(input("enter b:"))
    option=eval(input("enter a number 1 t0 4:"))
    if option==1:
        add(a,b)
    if option==2:
        sub(a,b)
    if option==3:
        mul(a,b)
    if option==4:
        div(a,b)

calculator()
# Out:
# option1 = addition:
# option2 = substraction:
# option1 = dicision:
# option4 = multiplication:
# enter a: 10
# enter b: 20
# enter a number 1 t0 4: 4
# 0.5
